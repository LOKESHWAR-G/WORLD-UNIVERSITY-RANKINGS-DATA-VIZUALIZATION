# %%
#import the warnings.
import warnings
warnings.filterwarnings("ignore")

# %%
#import the useful libraries.
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#read the data set of "bank telemarketing campaign" in inp0.
inp0= pd.read_csv("institution Data.csv")

# %%
df = pd.read_csv('institution Data.csv')

# %%
df.shape
# Out:
# (2200, 14)

# %% [markdown]
# ### This dataset has 2200 Rows and 14 Columns.

# %%
df.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
df.tail()
# Out:
#       world_rank                      institution   country  national_rank  \
# 2195         996        University of the Algarve  Portugal              7
# 2196         997            Alexandria University     Egypt              4
# 2197         998      Federal University of Ceará    Brazil             18
# 2198         999           University of A Coruña     Spain             40
# 2199        1000  China Pharmaceutical University     China             83
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# 2195                   367                567                 218
# 2196                   236                566                 218
# 2197                   367                549                 218
# 2198                   367                567                 218
# 2199                   367                567                 218
#
#       publications  influence  citations  broad_impact  patents  score  year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   world_rank            2200 non-null   int64
#  1   institution           2200 non-null   object
#  2   country               2200 non-null   object
#  3   national_rank         2200 non-null   int64
#  4   quality_of_education  2200 non-null   int64
#  5   alumni_employment     2200 non-null   int64
#  6   quality_of_faculty    2200 non-null   int64
#  7   publications          2200 non-null   int64
#  8   influence             2200 non-null   int64
#  9   citations             2200 non-null   int64
#  10  broad_impact          2000 non-null   float64
#  11  patents               2200 non-null   int64
#  12  score                 2200 non-null   float64
#  13  year                  2200 non-null   int64
# dtypes: float64(2), int64(10), object(2)
# ...

# %% [markdown]
# ### we are trying to get a simple statistical report for all the numerical columns in the data set

# %%
df.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %%
df.columns
# Out:
# Index(['world_rank', 'institution', 'country', 'national_rank',
#        'quality_of_education', 'alumni_employment', 'quality_of_faculty',
#        'publications', 'influence', 'citations', 'broad_impact', 'patents',
#        'score', 'year'],
#       dtype='object')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Checking if the data has null values or not.

# %%
df.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %% [markdown]
# ### Checking the percentage of missing values in each column.

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# world_rank              0.000000
# institution             0.000000
# country                 0.000000
# national_rank           0.000000
# quality_of_education    0.000000
# alumni_employment       0.000000
# quality_of_faculty      0.000000
# publications            0.000000
# influence               0.000000
# citations               0.000000
# broad_impact            9.090909
# patents                 0.000000
# score                   0.000000
# year                    0.000000
# dtype: float64

# %% [markdown]
# ### Missing Value Inspection

# %%
Value_Missing = df.isnull().sum().sort_values(ascending = False)
percent_missing = (df.isnull().sum() * 100 / len(df)).round(2).sort_values(ascending = False)
missing_data = pd.concat([Value_Missing, percent_missing], axis = 1, keys = ['Total', 'Percent'])
f, ax = plt.subplots(figsize = (10, 5))
plt.xticks(rotation = '90')
cplot = sns.barplot(x = missing_data.index, y = missing_data['Percent'], palette = 'bone_r', lw = 2, ec = 'black')
for count in cplot.patches:
    height = count.get_height()
    ax.annotate('{}'.format(height),xy = (count.get_x() + count.get_width()/2, height),
                    ha = 'center', va = 'bottom', size = 11, xytext = (0, 3), textcoords = 'offset points')
cplot.set_title('Missing Value Inspection', fontsize = 20, weight = 'bold')
cplot.set_ylabel('Count', fontsize = 15)
cplot.set_xlabel('Features', fontsize = 15);

# %%
df.broad_impact.fillna(0, inplace=True)

# %%
Value_Missing = df.isnull().sum().sort_values(ascending = False)
percent_missing = (df.isnull().sum() * 100 / len(df)).round(2).sort_values(ascending = False)
missing_data = pd.concat([Value_Missing, percent_missing], axis = 1, keys = ['Total', 'Percent'])
f, ax = plt.subplots(figsize = (10, 5))
plt.xticks(rotation = '90')
cplot = sns.barplot(x = missing_data.index, y = missing_data['Percent'], palette = 'bone_r', lw = 2, ec = 'black')
for count in cplot.patches:
    height = count.get_height()
    ax.annotate('{}'.format(height),xy = (count.get_x() + count.get_width()/2, height),
                    ha = 'center', va = 'bottom', size = 11, xytext = (0, 3), textcoords = 'offset points')
cplot.set_title('Missing Value Inspection', fontsize = 20, weight = 'bold')
cplot.set_ylabel('Count', fontsize = 15)
cplot.set_xlabel('Features', fontsize = 15);

# %%
df.isnull().sum()
# Out:
# world_rank              0
# institution             0
# country                 0
# national_rank           0
# quality_of_education    0
# alumni_employment       0
# quality_of_faculty      0
# publications            0
# influence               0
# citations               0
# broad_impact            0
# patents                 0
# score                   0
# year                    0
# dtype: int64

# %%
len(df.institution.unique())
# Out:
# 1024

# %%
len(df.country.unique())
# Out:
# 59

# %%
df.mean()
# Out:
# world_rank               459.590909
# national_rank             40.278182
# quality_of_education     275.100455
# alumni_employment        357.116818
# quality_of_faculty       178.888182
# publications             459.908636
# influence                459.797727
# citations                413.417273
# broad_impact             451.545000
# patents                  433.346364
# score                     47.798395
# year                    2014.318182
# dtype: float64

# %%
df.median()
# Out:
# world_rank               450.5
# national_rank             21.0
# quality_of_education     355.0
# alumni_employment        450.5
# quality_of_faculty       210.0
# publications             450.5
# influence                450.5
# citations                406.0
# broad_impact             447.0
# patents                  426.0
# score                     45.1
# year                    2014.0
# dtype: float64

# %%
df.std()
# Out:
# world_rank              304.320363
# national_rank            51.740870
# quality_of_education    121.935100
# alumni_employment       186.779252
# quality_of_faculty       64.050885
# publications            303.760352
# influence               303.331822
# citations               264.366549
# broad_impact            308.600387
# patents                 273.996525
# score                     7.760806
# year                      0.762130
# dtype: float64

# %%
df.var()
# Out:
# world_rank              92610.883046
# national_rank            2677.117668
# quality_of_education    14868.168622
# alumni_employment       34886.488848
# quality_of_faculty       4102.515913
# publications            92270.351358
# influence               92010.194174
# citations               69889.672098
# broad_impact            95234.198975
# patents                 75074.095530
# score                      60.230116
# year                        0.580843
# dtype: float64

# %% [markdown]
# ## UNIVARIATE ANALASYS

# %% [markdown]
# ### PIE CHART

# %%
x= df['country'].value_counts()
plt.pie(x, labels=x.index, autopct="%.0f%%",radius=3);

# %% [markdown]
# #### According to the pie chart USA has more number of institutions which are under 100 rankings in world rankings data.

# %%
sns.violinplot(x=df["patents"])
# Out:
# <AxesSubplot:xlabel='patents'>

# %% [markdown]
# #### From this violin plot we can see that most of the institutions have patents between 0-200 in 2012-2013 and 600-800 patents in the years 2014-2015.

# %%
sns.boxplot(df.score)
plt.show()

# %% [markdown]
# #### this above box plot we can observe most of the institutions has the score less than 50 and only few institutions has more than 80 as a its score.

# %%
plt.hist(df['quality_of_education'])
# Out:
# (array([ 131.,  115.,  174.,   74.,   72.,   74.,   74.,   72.,   74.,
#         1340.]),
#  array([  1. ,  37.6,  74.2, 110.8, 147.4, 184. , 220.6, 257.2, 293.8,
#         330.4, 367. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### The above graph represents the distribution of numerical column “Quality of education”.Hear we can see that more than 1300 institutions out of2201 institutions had 350+ points of Quality education

# %%
plt.hist(df['patents'])
# Out:
# (array([290., 264., 186., 180., 195., 158., 172., 187., 354., 214.]),
#  array([  1.,  88., 175., 262., 349., 436., 523., 610., 697., 784., 871.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
df.groupby("country")["publications"].mean().plot(kind='bar',figsize=(20,10))
plt.xlabel("country",fontdict={'fontsize':25,'fontweight':3,'color':'Red'})
plt.ylabel("publications",fontdict={'fontsize':25,'fontweight':3,'color':'Blue'})

plt.show()

# %% [markdown]
# #### In this Bar graph we can see that Portugal and UAE has maximum and mostly equal publications in world rankings. And Singapore has the least publications.

# %%
df['year'].value_counts().plot(kind = "bar",figsize=(15,10))
plt.xlabel("YEAR",fontdict={'fontsize':15,'fontweight':3,'color':'Red'})
plt.ylabel("COUNT",fontdict={'fontsize':15,'fontweight':3,'color':'Blue'})
plt.show()

# %%
df.groupby("country")["score"].mean().plot(kind='bar',figsize=(20,10))
plt.xlabel("country",fontdict={'fontsize':25,'fontweight':3,'color':'Red'})
plt.ylabel("score",fontdict={'fontsize':25,'fontweight':3,'color':'Blue'})

plt.show()

# %%
df.groupby("year")["quality_of_education"].mean().plot(kind='bar',figsize=(20,10))
plt.xlabel("year",fontdict={'fontsize':25,'fontweight':3,'color':'Red'})
plt.ylabel("quality_of_education",fontdict={'fontsize':25,'fontweight':3,'color':'Blue'})

plt.show()

# %% [markdown]
# #### in this bar graph we can see quality of education is nearly 60 as average in 2012-2013 years(took 100 institutions as analysis) and in 2014-2015 quality of education is nearly 300 as average(took 100 institutions as analysis).

# %%
 df.groupby("year").mean()['quality_of_faculty'].plot(kind='line',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# #### In this line graph we see that in the year 2012-2013 the average quality of faculty is nearly 60(took 100 institutions as analysis). And in year 2014-2015 quality of faculty is nearby 200(took 100 institutions as analysis).

# %%
x = df["citations"]
y = df["year"]

plt.scatter(x, y,)
plt.show()

# %%
correlation = df.corr()
correlation
# Out:
#                       world_rank  national_rank  quality_of_education  \
# world_rank              1.000000       0.238553              0.676166
# national_rank           0.238553       1.000000              0.211975
# quality_of_education    0.676166       0.211975              1.000000
# alumni_employment       0.668529       0.135342              0.606421
# quality_of_faculty      0.663864       0.222833              0.786181
# publications            0.923037       0.326857              0.624657
# influence               0.895871       0.161086              0.645641
# citations               0.856573       0.186797              0.630455
# broad_impact            0.953006       0.214437              0.637312
# patents                 0.698214       0.159440              0.528120
# score                  -0.549098      -0.199756             -0.600541
# year                    0.320844       0.102951              0.427732
#
# ...

# %%
plt.subplots(figsize=(20,8))
sns.heatmap(correlation,annot=True,
           xticklabels = correlation.columns.values,
           yticklabels = correlation.columns.values);
plt.show()

# %% [markdown]
# #### Correlation map is just to understand the dependance of columns with each other also gives the correlation values. From the above graph we can conclude that the columns are less dependent on each other whose correlation value is equal to 1.

# %%
sns.pairplot(data=df,vars=["quality_of_faculty","quality_of_education","national_rank"])
plt.show()

# %% [markdown]
# #### The above graph is a pair plot is used to know the grid axis of separate clusters .  To create a pair plot the data is shared across the y-axes across a single row, and the x-axes across a single column.
